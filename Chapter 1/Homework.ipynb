# %% [markdown]
# # Question 1
# What's the version of NumPy that you installed?

# %%
np.__version__
# Out:
# '1.24.3'

# %%
car_price = pd.read_csv('./data.csv')
car_price.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# # Question 2
# How many records are in the dataset?

# %%
car_price.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
# Got it wrong
car_price.shape[0]
# Out:
# 11914

# %% [markdown]
# # Question 3
# Who are the most frequent car manufacturers (top-3) according to the dataset?

# %%
car_price.groupby('Make').Make.count().nlargest(n=3)
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %%
# Another way
car_price['Make'].value_counts().head()
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Name: count, dtype: int64

# %% [markdown]
# # Question 4
# What's the number of unique Audi car models in the dataset?

# %%
car_price[car_price['Make']=='Audi'].Model.nunique()
# Out:
# 34

# %% [markdown]
# # Question 5
# How many columns in the dataset have missing values? <br/>
# Ans: 5

# %%
car_price.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
## got it wrong
(car_price.isnull().sum() !=0).sum()
# Out:
# 5

# %% [markdown]
# # Question 6
#     1. Find the median value of "Engine Cylinders" column in the dataset.
#     2. Next, calculate the most frequent value of the same "Engine Cylinders".
#     3. Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.
#     4. Now, calculate the median value of "Engine Cylinders" once again. Has it changed?

# %%
#1
car_price['Engine Cylinders'].median()
# Out:
# 6.0

# %%
#2
frequent = car_price['Engine Cylinders'].mode()
frequent
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
#3
# Number of rows having null values in the Engine Cylinders column
car_price['Engine Cylinders'].isna().sum()
# Out:
# 30

# %%
car_price['Engine Cylinders'].fillna(frequent[0], inplace=True)

# %%
#4 Number of rows having null values in the Engine Cylinders column

car_price['Engine Cylinders'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Question 7
#     1. Select all the "Lotus" cars from the dataset.
#     2.Select only columns "Engine HP", "Engine Cylinders".
#     3. Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).
#     4. Get the underlying NumPy array. Let's call it X.
#     5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
#     6. Compute the inverse of XTX.
#     7. Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].
#     8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#     9. What's the value of the first element of w?

# %%
#1 
lotus_cars = car_price[car_price.Make == 'Lotus']
lotus_cars
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
#2
lotus_engine_info =lotus_cars[['Engine HP','Engine Cylinders']]
lotus_engine_info
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
#3 
lotus_engine_info.drop_duplicates()
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
#4
x = lotus_engine_info.values
x
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
#5
XTX = x.T.dot(x)
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
#6
inv_XTX = np.linalg.inv(XTX)
inv_XTX
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %%
#7
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %%
#8
w = (inv_XTX.dot(x.T)).dot(y)
w
# Out:
# array([  4.59494481, -63.56432501])

# %%
#9
w[0].round(4)
# Out:
# 4.5949
